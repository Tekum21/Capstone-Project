# %% [markdown]
#  ## Importing/Installing Packages.

# %%
#Intalling/ importing packages
import os #This provide fucntion for the interaction with the operating system.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') #this helps filter uneccesary warnings.

# %% [markdown]
# ## 1. Loading the Raw Data.

# %%
#loading raw data
#Raw data= data frame(df)
#Report=pd.read_csv("breach_report.csv")
Report=pd.read_csv(r"C:\Users\tnjok\OneDrive\Desktop\Datasets\breach_report.csv")
Report
# Out:
#                                 Name of Covered Entity State  \
# 0                      Falcon Group International Corp    NY
# 1                           Glacier Medical Associates    MT
# 2                  Discovery Practice Management, Inc.    CA
# 3              Wisconsin Department of Health Services    WI
# 4                     East Jordan Family Health Center    MI
# ..                                                 ...   ...
# 789                               Adirondacks ACO, LLC    NY
# 790                                      Optum360, LLC    MN
# 791                         Southwest Gastroenterology    IL
# 792  Dominion Dental Services, Inc., Dominion Natio...    VA
# 793  EyeCare Partners, LLC [on behalf of affiliated...    MO
#
#      Covered Entity Type  Individuals Affected Breach Submission Date  \
# 0    Healthcare Provider                  1900               6/9/2021
# 1    Healthcare Provider                  3007               6/7/2021
# ...

# %%
Report.columns
# Out:
# Index(['Name of Covered Entity', 'State', 'Covered Entity Type',
#        'Individuals Affected', 'Breach Submission Date', 'Type of Breach',
#        'Location of Breached Information', 'Business Associate Present',
#        'Web Description'],
#       dtype='object')

# %%
# Deleting the column "Web Description" from the Report because it is of no importance
del Report['Web Description']

# %%
Report.describe(include='all')
# Out:
#        Name of Covered Entity State  Covered Entity Type  \
# count                     794   793                  794
# unique                    759    50                    4
# top        University of Utah    TX  Healthcare Provider
# freq                        4    70                  610
# mean                      NaN   NaN                  NaN
# std                       NaN   NaN                  NaN
# min                       NaN   NaN                  NaN
# 25%                       NaN   NaN                  NaN
# 50%                       NaN   NaN                  NaN
# 75%                       NaN   NaN                  NaN
# max                       NaN   NaN                  NaN
#
#         Individuals Affected Breach Submission Date       Type of Breach  \
# count           7.940000e+02                    794                  794
# unique                   NaN                    343                    5
# ...

# %%
Report.describe()
# Out:
#        Individuals Affected  Web Description
# count          7.940000e+02              0.0
# mean           7.847364e+04              NaN
# std            4.773484e+05              NaN
# min            5.000000e+02              NaN
# 25%            1.532750e+03              NaN
# 50%            4.341500e+03              NaN
# 75%            3.336875e+04              NaN
# max            1.150000e+07              NaN

# %%
Report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 794 entries, 0 to 793
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Name of Covered Entity            794 non-null    object
#  1   State                             793 non-null    object
#  2   Covered Entity Type               794 non-null    object
#  3   Individuals Affected              794 non-null    int64
#  4   Breach Submission Date            794 non-null    object
#  5   Type of Breach                    794 non-null    object
#  6   Location of Breached Information  794 non-null    object
#  7   Business Associate Present        794 non-null    object
#  8   Web Description                   0 non-null      float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 56.0+ KB

# %%
Report.shape
# Out:
# (794, 8)

# %%
#To print out just the top 5 rows of the dataset.
Report.head(5)
# Out:
#                     Name of Covered Entity State  Covered Entity Type  \
# 0          Falcon Group International Corp    NY  Healthcare Provider
# 1               Glacier Medical Associates    MT  Healthcare Provider
# 2      Discovery Practice Management, Inc.    CA   Business Associate
# 3  Wisconsin Department of Health Services    WI          Health Plan
# 4         East Jordan Family Health Center    MI  Healthcare Provider
#
#    Individuals Affected Breach Submission Date  \
# 0                  1900               6/9/2021
# 1                  3007               6/7/2021
# 2                 13611               6/5/2021
# 3                  2868               6/4/2021
# 4                  1151               6/4/2021
#
#                    Type of Breach Location of Breached Information  \
# 0  Unauthorized Access/Disclosure        Electronic Medical Record
# 1             Hacking/IT Incident                   Network Server
# ...

# %%
#To print out just the last 5 rows of the dataset.
Report.tail(5)
# Out:
#                                 Name of Covered Entity State  \
# 789                               Adirondacks ACO, LLC    NY
# 790                                      Optum360, LLC    MN
# 791                         Southwest Gastroenterology    IL
# 792  Dominion Dental Services, Inc., Dominion Natio...    VA
# 793  EyeCare Partners, LLC [on behalf of affiliated...    MO
#
#      Covered Entity Type  Individuals Affected Breach Submission Date  \
# 789   Business Associate                 39649             07/02/2019
# 790   Business Associate              11500000             07/01/2019
# 791  Healthcare Provider                  1600             06/28/2019
# 792          Health Plan               2964778             06/21/2019
# 793  Healthcare Provider                141165             06/19/2019
#
#           Type of Breach Location of Breached Information  \
# 789  Hacking/IT Incident                            Email
# ...

# %%
# Converting the Breach Submission date to('%m/%d/%Y') format

Report['Breach Submission Date'] = pd.to_datetime(Report['Breach Submission Date']).dt.strftime('%m/%d/%Y')

Report.head()
# Out:
#                     Name of Covered Entity State  Covered Entity Type  \
# 0          Falcon Group International Corp    NY  Healthcare Provider
# 1               Glacier Medical Associates    MT  Healthcare Provider
# 2      Discovery Practice Management, Inc.    CA   Business Associate
# 3  Wisconsin Department of Health Services    WI          Health Plan
# 4         East Jordan Family Health Center    MI  Healthcare Provider
#
#    Individuals Affected Breach Submission Date  \
# 0                  1900             06/09/2021
# 1                  3007             06/07/2021
# 2                 13611             06/05/2021
# 3                  2868             06/04/2021
# 4                  1151             06/04/2021
#
#                    Type of Breach Location of Breached Information  \
# 0  Unauthorized Access/Disclosure        Electronic Medical Record
# 1             Hacking/IT Incident                   Network Server
# ...

# %%
Report["Breach Submission Date"]=pd.to_datetime(Report["Breach Submission Date"])
Report["Breach Submission Date"]
# Out:
# 0     2021-06-09
# 1     2021-06-07
# 2     2021-06-05
# 3     2021-06-04
# 4     2021-06-04
#          ...
# 789   2019-07-02
# 790   2019-07-01
# 791   2019-06-28
# 792   2019-06-21
# 793   2019-06-19
# Name: Breach Submission Date, Length: 794, dtype: datetime64[ns]

# %%
Report.head()
# Out:
#                     Name of Covered Entity State  Covered Entity Type  \
# 0          Falcon Group International Corp    NY  Healthcare Provider
# 1               Glacier Medical Associates    MT  Healthcare Provider
# 2      Discovery Practice Management, Inc.    CA   Business Associate
# 3  Wisconsin Department of Health Services    WI          Health Plan
# 4         East Jordan Family Health Center    MI  Healthcare Provider
#
#    Individuals Affected Breach Submission Date  \
# 0                  1900             2021-06-09
# 1                  3007             2021-06-07
# 2                 13611             2021-06-05
# 3                  2868             2021-06-04
# 4                  1151             2021-06-04
#
#                    Type of Breach Location of Breached Information  \
# 0  Unauthorized Access/Disclosure        Electronic Medical Record
# 1             Hacking/IT Incident                   Network Server
# ...

# %%
Report["Breach Submission Date"].dt.year
# Out:
# 0      2021
# 1      2021
# 2      2021
# 3      2021
# 4      2021
#        ...
# 789    2019
# 790    2019
# 791    2019
# 792    2019
# 793    2019
# Name: Breach Submission Date, Length: 794, dtype: int64

# %%
Report["Breach Submission Date"].dt.month
# Out:
# 0      6
# 1      6
# 2      6
# 3      6
# 4      6
#       ..
# 789    7
# 790    7
# 791    6
# 792    6
# 793    6
# Name: Breach Submission Date, Length: 794, dtype: int64

# %%
Report["Breach Submission Date"].dt.day
# Out:
# 0       9
# 1       7
# 2       5
# 3       4
# 4       4
#        ..
# 789     2
# 790     1
# 791    28
# 792    21
# 793    19
# Name: Breach Submission Date, Length: 794, dtype: int64

# %%
# Adding new columns for Breach Yr & Breach Month
Report['Breach Yr']= Report['Breach Submission Date'].dt.year
Report['Breach Month']= Report['Breach Submission Date'].dt.month

#Converting from str to int
#Report['Breach Month']= Report['Breach Month'].astype('int32')
#Report['Breach Yr']= Report['Breach Yr'].astype('int32')
Report.head()
# Out:
#                     Name of Covered Entity State  Covered Entity Type  \
# 0          Falcon Group International Corp    NY  Healthcare Provider
# 1               Glacier Medical Associates    MT  Healthcare Provider
# 2      Discovery Practice Management, Inc.    CA   Business Associate
# 3  Wisconsin Department of Health Services    WI          Health Plan
# 4         East Jordan Family Health Center    MI  Healthcare Provider
#
#    Individuals Affected Breach Submission Date  \
# 0                  1900             2021-06-09
# 1                  3007             2021-06-07
# 2                 13611             2021-06-05
# 3                  2868             2021-06-04
# 4                  1151             2021-06-04
#
#                    Type of Breach Location of Breached Information  \
# 0  Unauthorized Access/Disclosure        Electronic Medical Record
# 1             Hacking/IT Incident                   Network Server
# ...

# %%
Report.tail()
# Out:
#                                 Name of Covered Entity State  \
# 789                               Adirondacks ACO, LLC    NY
# 790                                      Optum360, LLC    MN
# 791                         Southwest Gastroenterology    IL
# 792  Dominion Dental Services, Inc., Dominion Natio...    VA
# 793  EyeCare Partners, LLC [on behalf of affiliated...    MO
#
#      Covered Entity Type  Individuals Affected Breach Submission Date  \
# 789   Business Associate                 39649             2019-07-02
# 790   Business Associate              11500000             2019-07-01
# 791  Healthcare Provider                  1600             2019-06-28
# 792          Health Plan               2964778             2019-06-21
# 793  Healthcare Provider                141165             2019-06-19
#
#           Type of Breach Location of Breached Information  \
# 789  Hacking/IT Incident                            Email
# ...

# %%
sum(Report['Individuals Affected'])
# Out:
# 62308067

# %%
# sorting individuals affected in descending order
Report=Report.sort_values(by="Individuals Affected",ascending=False)
#Top 20 entities affected
Report.head(20)
# Out:
#                                 Name of Covered Entity State  \
# 790                                      Optum360, LLC    MN
# 259                   Florida Healthy Kids Corporation    FL
# 34                         20/20 Eye Care Network, Inc    FL
# 792  Dominion Dental Services, Inc., Dominion Natio...    VA
# 73                   NEC Networks, LLC d/b/a CaptureRx    TX
# 228                                    The Kroger Co.     OH
# 453                             EyeMed Vision Care LLC    OH
# 322                              MEDNAX Services, Inc.    FL
# 286                      American Anesthesiology, Inc.    NY
# 604                               Magellan Health Inc.    AZ
# 338                          Dental Care Alliance, LLC    FL
# 353                                   US Fertility LLC    MD
# 403                          Luxottica of America Inc.    OH
# 154                       Personal Touch Holding Corp.    NY
# ...

# %%
# Finding top 10 states with most breaches. 
D = Report.groupby('State',as_index=None).agg({"Individuals Affected":"sum"})
D.sort_values("Individuals Affected", ascending= False,ignore_index=True).head(10)
# Out:
#   State  Individuals Affected
# 0    MN              11871639
# 1    FL              11043067
# 2    OH               4972346
# 3    NY               4454597
# 4    CA               3908209
# 5    TX               3600042
# 6    VA               3169455
# 7    PA               1592693
# 8    AZ               1458296
# 9    MD               1374745

# %%
# Ranking the type of data breach by the number of individuals affected. 
D = Report.groupby('Type of Breach',as_index=None).agg({"Individuals Affected":"sum"})
D.sort_values("Individuals Affected", ascending= False,ignore_index=True).head(10)
# Out:
#                    Type of Breach  Individuals Affected
# 0             Hacking/IT Incident              58416763
# 1  Unauthorized Access/Disclosure               2994170
# 2               Improper Disposal                625866
# 3                            Loss                144045
# 4                           Theft                127223

# %%
Report=Report.sort_values(by= "Individuals Affected", ascending =False)

# least 20 breaches reported
Report.tail(20)
# Out:
#                               Name of Covered Entity State  \
# 82                        Boston Children’s Hospital    MA
# 135                   Southern Orthopaedic Surgeons     AL
# 529                                       Humana Inc    KY
# 331                             TNMO Healthcare, LLC    TN
# 167                              University of Miami    FL
# 744                         Outreach Health Services    TX
# 717                            INTEGRIS Health, Inc.    OK
# 366           Planned Parenthood of Metro Washington    DC
# 688      Armada Physical Therapy of Albuquerque, LLC    NM
# 673  North Texas Institute of Neurology and Headache    TX
# 41                      Beech Acres Parenting Center    OH
# 571                                    Jim Dinh, DC     TX
# 17                      Monroe County Health Center     WV
# 638                     Customized Computer Software    TX
# 755          Choctaw Nation Health Service Authority    OK
# ...

# %%
# Filtering data by individual months and years.
Month =6
Year = 2021
May_2021_breach = Report.loc[(Report["Breach Yr"] ==Year) & (Report["Breach Month"] == Month)]
May_2021_breach
sum(May_2021_breach["Individuals Affected"])
# Out:
# 65867

# %%
# Investigating the years in our dataset.
Report["Breach Yr"].unique()
# Out:
# array([2019, 2021, 2020], dtype=int64)

# %%
Report.columns
# Out:
# Index(['Name of Covered Entity', 'State', 'Covered Entity Type',
#        'Individuals Affected', 'Breach Submission Date', 'Type of Breach',
#        'Location of Breached Information', 'Business Associate Present',
#        'Breach Yr', 'Breach Month'],
#       dtype='object')

# %%
# Creating a new sub dataset that contains the total number of affected individuals for each month.
# This is to permit us do a closer analysis by months.
New_data = pd.read_excel(r"C:\Users\tnjok\OneDrive\Desktop\Datasets\Breach Summary.xlsx")
New_data
# Out:
#    Breach Month & Year  Totoal Individuals Affected   Month
# 0           2019-11-30                       473556  Nov.19
# 1           2019-12-31                       182276  Dec.19
# 2           2020-01-31                       314963  Jan.20
# 3           2020-02-29                       524300  Feb.20
# 4           2020-03-31                       821788  Mar.20
# 5           2020-04-30                       550352  Apr.20
# 6           2020-05-31                      1058291  May.20
# 7           2020-06-30                      1753113  Jun.20
# 8           2020-07-31                      1306864  Jul.20
# 9           2020-08-31                      1561254  Aug.20
# 10          2020-09-30                      4938532  Sep.20
# 11          2020-10-31                      2921553  Oct.20
# 12          2020-11-30                      2170750  Nov.20
# 13          2020-12-31                      4683121  Dec.20
# 14          2021-01-31                      5815454  Jan.21
# ...

# %%
sum(New_data["Totoal Individuals Affected"])
# Out:
# 44956843

# %%
# create the time series plot
fig,ax=plt.subplots(figsize=(10,8))
sns.lineplot(x = "Month", y = "Totoal Individuals Affected",data = New_data)
plt.xticks(rotation = 90)
plt.show()

# %%
# create the time series plot
fig,ax=plt.subplots(figsize=(10,8))
sns.lineplot(x = "Breach Month & Year", y = "Totoal Individuals Affected",data = New_data)
plt.title("Individuals Affected",color='red',fontsize=14)
plt.xticks(rotation = 25)

plt.show()

# %%
#Investigating the distribution of breaches.
fig,ax=plt.subplots(figsize=(10,8))
Rev=New_data["Totoal Individuals Affected"].values
ax=sns.distplot(Rev,color="blue")
#Calculating the mean
mean=(New_data["Totoal Individuals Affected"].mean())
print(mean)
#ploting the mean
plt.axvline(mean,color="red",label="Av Individuals Affected")
plt.title('Histogram showing the distribution of the number of breaches',color='red',fontsize=14)
plt.legend()
plt.grid()
# Out:
# 2247842.15

# %%
#Example1: Bar plot showing the Type of Breaches and the Affected Individuals
fig,ax=plt.subplots(figsize=(10,8))
ax=sns.barplot(y="Totoal Individuals Affected",x="Month",data=New_data,ci=None,
               palette = "Reds")
plt.title("Total Number of Breaches Reported in Their Respective Months and Years", color='blue',fontsize=14) 
plt.xticks(rotation = 60)
plt.show(fig)

# %%
# Number of breaches per yer
Report["Breach Yr"].value_counts()
# Out:
# 2020    421
# 2021    292
# 2019     81
# Name: Breach Yr, dtype: int64

# %%
Report["Individuals Affected"].dtype
# Out:
# dtype('int64')

# %%
Report["Breach Month"].value_counts()
# Out:
# 3     88
# 5     85
# 4     85
# 9     84
# 12    76
# 2     69
# 10    61
# 11    58
# 6     51
# 1     50
# 7     48
# 8     39
# Name: Breach Month, dtype: int64

# %%
# %matplotlib inline

# %%
# Investigating the number of each Type of Breach that was reported
data=Report["Type of Breach"].value_counts()
data
# Out:
# Hacking/IT Incident               578
# Unauthorized Access/Disclosure    159
# Theft                              31
# Loss                               15
# Improper Disposal                  11
# Name: Type of Breach, dtype: int64

# %%
#Using matplotlib
pie, ax = plt.subplots(figsize=[10,6])
labels = data.keys()
plt.pie(x=data, autopct="%.1f%%", explode=[0.05]*5, labels=labels, pctdistance=0.5)
plt.title("Type of Breach By Percentage", fontsize=14,color='red');
pie.savefig("dataPieChart.png")

# %%
#Investigating with most breaches States
data_ST=Report["State"].value_counts()
data_ST
# Out:
# TX    70
# NY    69
# CA    65
# FL    44
# PA    38
# OH    37
# MI    31
# IL    28
# MA    28
# MD    24
# MO    22
# GA    21
# WI    20
# MN    20
# NJ    19
# NC    17
# CT    17
# VA    16
# CO    15
# AR    15
# IN    13
# TN    12
# NM    10
# IA    10
# WA     9
# LA     9
# DE     9
# UT     9
# KY     9
# SC     8
# AZ     8
# WV     7
# OK     6
# NE     6
# NV     5
# KS     5
# ME     4
# NH     4
# MS     4
# AL     4
# MT     4
# VT     3
# OR     3
# DC     3
# AK     3
# WY     3
# ID     3
# ND     2
# HI     1
# RI     1
# Name: State, dtype: int64

# %%
# Investigating the number breach associated with each Covered Entity Type
data_CET=Report["Covered Entity Type"].value_counts()
data_CET
# Out:
# Healthcare Provider          610
# Health Plan                   91
# Business Associate            91
# Healthcare Clearing House      2
# Name: Covered Entity Type, dtype: int64

# %%
#Using matplotlib
pie, ax = plt.subplots(figsize=[10,6])
labels = data_CET.keys()
plt.pie(x=data_CET, autopct="%.1f%%", explode=[0.05]*4, labels=labels, pctdistance=0.5)
plt.title("Covered Entity Breaches", fontsize=14, color='red');
pie.savefig("dataPieChart.png")

# %%
# Names of Names of Covered Entity Higher Affect
Report["Name of Covered Entity"].value_counts()
# Out:
# University of Utah                      4
# Walgreen Co.                            4
# Montefiore Medical Center               3
# Walmart Inc.                            3
# University of Missouri Health Care      3
#                                        ..
# City Dental                             1
# Nevada Health Centers, Inc.             1
# Nebraska Methodist Health System        1
# SOUTHERN INDIAN HEALTH COUNCIL, INC.    1
# Florida Orthopaedic Institute           1
# Name: Name of Covered Entity, Length: 759, dtype: int64

# %%
# Investigating breach location
Report["Location of Breached Information"].value_counts()
# Out:
# Network Server                                                                329
# Email                                                                         265
# Paper/Films                                                                    54
# Other                                                                          36
# Electronic Medical Record                                                      30
# Other Portable Electronic Device                                               10
# Laptop                                                                          9
# Electronic Medical Record, Network Server                                       8
# Email, Network Server                                                           6
# Network Server, Other                                                           6
# Desktop Computer                                                                6
# ...

# %%
# Inestigating number of Business Associates Involved
Report["Business Associate Present"].value_counts()
# Out:
# No     512
# Yes    282
# Name: Business Associate Present, dtype: int64

# %%
# Total number of Individual Affected by Year
Report[["Individuals Affected","Breach Yr"]].groupby("Breach Yr").agg({'Individuals Affected':'sum'})
# Out:
#            Individuals Affected
# Breach Yr
# 2019                   18007056
# 2020                   22604881
# 2021                   21696130

# %%
# Investigating the number of each Breach Type
Breach_count= Report["Type of Breach"].value_counts()
Breach_count
# Out:
# Hacking/IT Incident               578
# Unauthorized Access/Disclosure    159
# Theft                              31
# Loss                               15
# Improper Disposal                  11
# Name: Type of Breach, dtype: int64

# %%
#Example1: Bar plot showing the Type of Breaches and the Affected Individuals
fig,ax=plt.subplots(figsize=(10,8))
ax=sns.barplot(y="Type of Breach",x="Individuals Affected",data=Report,ci=None,
               hue="Breach Yr",palette = "Reds",estimator = np.mean)
plt.title("Types of Breach vs Number of individuals Affected in the various years") 
plt.savefig("add_annotation_to_bars_in_barplot_Seaborn_Python.png")
plt.show(fig)


#Notes:
# The bars take the mean of the Revenue by default.
#create the mean of the Revenue of our data frame.
#Report[["Revenue","Month_ID"]].groupby("Month_ID").agg({'Revenue':'mean'})
